# %% [markdown]
# #Newton Fractals
#
# Newton Raphson method to find rate of convergence for diferent roots on a polynomial based .
#
# **Group:**  2 - 28
#
# *   Kevin Leonardo Alvarez Mora
# *   Brayan Rolando Jr Portela Cabrera
# *   Christian Camilo Pabon Useche Grupo

# %% [markdown]
# #Fractal: $z^3 - 2z + 2$

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f1(z):
    return (z**3) - 2*z + 2

def df1(z):
    return 3*(z**2) - 2

def newton_set2(z_c_r=0, z_c_i=0, zh = 10, zw=10, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = -1.76929235423863
    r2 = complex(0.884646177119316,-1*0.589742805022206)
    r3 = complex(0.884646177119316,0.589742805022206)

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df1(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f1(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color yellow
                    pixels[height-y-1,x] = (255 - count*multcol,196 , 0)
                elif abs(z-r2)<=eps:
                    # color blue
                    pixels[height-y-1,x] = (18, 124 - count*multcol, 179)
                elif abs(z-r3)<=eps:
                    # color purple
                    pixels[height-y-1,x] = (83, 18, 179 - count*multcol)
                else:  
                    # color white
                    pixels[height-y-1,x] = (255,255, 255)
 
    return pixels

def display2(z_c_r=0, z_c_i=0, zh = 10, zw=10, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set2(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=z^3 - 2z + 2' )
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# ##Plot of $f(z)=z^3 - 2z + 2$

# %%
x1 = np.linspace(-2.0,2.0,100)
def f1(z):
    return (z**3) - 2*z + 2

fig, ax = plt.subplots()
ax.plot(x1,f1(x1))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x) = x^3 - 2x + 2')
plt.xlabel('x')
plt.ylabel('y = f(x)');

# %% [markdown]
# **Analysis:** Based on The plot of the funciton we can observe that there is only one posible root on the Real set, as we observed the other ones are actuali in the complex plane.

# %% [markdown]
# ## *Fractal visualizations*

# %%
print("zoom out")
display2(zoom=1)
display2(zoom=2)
display2(zoom=3)
display2(zoom=4)
display2(zoom=5)
# Out:
# zoom out
# Z region from ( -5.0 , -5.0 ) to ( 5.0 , 5.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -10.0 , -10.0 ) to ( 10.0 , 10.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -15.0 , -15.0 ) to ( 15.0 , 15.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -20.0 , -20.0 ) to ( 20.0 , 20.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -25.0 , -25.0 ) to ( 25.0 , 25.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print("zoom in")
display2(zoom=1)
display2(zoom=1/2)
display2(zoom=1/3)
display2(zoom=1/4)
display2(zoom=1/5)
display2(zoom=1/10)
display2(zoom=1/20)
display2(zoom=1/30)
# Out:
# zoom in
# Z region from ( -5.0 , -5.0 ) to ( 5.0 , 5.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.6666666666666665 , -1.6666666666666665 ) to ( 1.6666666666666665 , 1.6666666666666665 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.25 , -1.25 ) to ( 1.25 , 1.25 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# ...

# %% [markdown]
# **Analysis:** Based on The plot of the fractal we can observe how this function tends to converge all the rots with an equal ammount of values, the real one in yellow.
#
# The complex roots represented by the blue and purple colors seem to be more common and wider in our fractal when we zoom in, this may indicate that when in the complex plane the evaluation of a complex number tends to get near to the complex root without considering the real part of it.
#
# The white tainted areas are parts of the fractals where the expresion converges to no root, by exammining our fractal we can coclude that for some set of values there is diverge.

# %% [markdown]
# #Fractal: $sin(z)$

# %% [markdown]
# ## *Plot of* $f(z) = sin(z)$

# %%
import math
import cmath
import numpy as np
import matplotlib.pyplot as plt

x2 = np.linspace(-4*np.pi,4*np.pi,100)
def f2(z):
    return np.sin(z)

fig, ax = plt.subplots()
ax.plot(x2,f2(x2))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x) = sin(z)')
plt.xlabel('x')
plt.ylabel('y = f(x)');

# %% [markdown]
# ## Fractal visualizations

# %%
import math
import cmath
import matplotlib.pyplot as plt
import numpy as np

def f2(z):
    return cmath.sin(z)

def df2(z):
    return cmath.cos(z)

def newton_set2(z_c_r=0, z_c_i=0, zh = 10, zw=10, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed
    
    # Bounding roots
    r1 = cmath.pi
    r2 = cmath.pi*3
    r3 = cmath.pi*2
    r4 = 0
    r5 = cmath.pi*-4
    r6 = cmath.pi*-2
    r7 = cmath.pi*-1
    r8 = cmath.pi*-3
    r9 = cmath.pi*4

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df2(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f2(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color orange
                    pixels[height-y-1,x] = (255 - count*multcol,104,25)
                elif abs(z-r2)<=eps:
                    # color teal
                    pixels[height-y-1,x] = (44,184 - count*multcol,177)
                elif abs(z-r3)<=eps:
                    # color dark purple
                    pixels[height-y-1,x] = (74,44,184 - count*multcol)
                elif abs(z-r4)<=eps:
                    # color dark blue
                    pixels[height-y-1,x] = (46,44,255 - count*multcol)
                elif abs(z-r5)<=eps:
                    # color  dark yellow
                    pixels[height-y-1,x] = (255 - count*multcol,210,0)
                elif abs(z-r6)<=eps:
                    # color yellow
                    pixels[height-y-1,x] = (255, 215 - count*multcol,25)
                elif abs(z-r7)<=eps:
                    # color green
                    pixels[height-y-1,x] = (25, 255, 171 - count*multcol) 
                elif abs(z-r8)<=eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol,2,1)
                elif abs(z-r9)<=eps:
                    # color pink
                    pixels[height-y-1,x] = (255, 0, 132 - count*multcol)            
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

def display3(z_c_r=1.75, z_c_i=1.75, zh = 10, zw=10, width=300, height=300, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set2(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=z^3 - 2z + 2' )
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
display3(zoom=1)
display3(zoom=2)
display3(zoom=3)
display3(zoom=4)
display3(zoom=5)
# Out:
# zoom out
# Z region from ( -3.25 , -3.25 ) to ( 6.75 , 6.75 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -8.25 , -8.25 ) to ( 11.75 , 11.75 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -13.25 , -13.25 ) to ( 16.75 , 16.75 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -18.25 , -18.25 ) to ( 21.75 , 21.75 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -23.25 , -23.25 ) to ( 26.75 , 26.75 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print("zoom in")
display3(zoom=1)
display3(zoom=1/2)
display3(zoom=1/3)
display3(zoom=1/4)
display3(zoom=1/5)
display3(zoom=1/10)
display3(zoom=1/12)
display3(zoom=1/15)
# Out:
# zoom in
# Z region from ( -3.25 , -3.25 ) to ( 6.75 , 6.75 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.75 , -0.75 ) to ( 4.25 , 4.25 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( 0.08333333333333348 , 0.08333333333333348 ) to ( 3.4166666666666665 , 3.4166666666666665 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( 0.5 , 0.5 ) to ( 3.0 , 3.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( 0.75 , 0.75 ) to ( 2.75 , 2.75 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( 1.25 , 1.25 ) to ( 2.25 , 2.25 )
# ...

# %% [markdown]
# **Analysis:** As a sine function, this one posses the same root properties that it's real counterpart posses , there exists a root in every point delimited by the following expression.
#
# $$ z = \pi n \ \;; n \in \mathbb{N}$$
#
# So we can assure there are infinite roots, all of them within the reals set, tha explains why this fractal representation is vertical.
#
# By the general expression of the root we can say that the lottle sets that appear on the borderline between colors have the same colors that its counterpart, this may indicate that for some values between two different numbers from $\mathbb{N}$ the Newton evaluation converges to the oposite root.

# %% [markdown]
# #Fractal: $z^5  - 3iz^3 -5 $

# %% [markdown]
# ## *Plot of:* $ f(z) = z^5  - 3iz^3 -5 $

# %%
import math
import cmath
import numpy as np
import matplotlib.pyplot as plt

x3 = np.linspace(-2,2,100)
def f3(z):
    return z**5  - 3j * z**3 - 5 

fig, ax = plt.subplots()
ax.plot(x3,f3(x3))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x) = z^5 - 3iz^3 - 5')
plt.xlabel('x')
plt.ylabel('y = f(x)');
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## Fractal visualizations

# %%
import math
import cmath
import matplotlib.pyplot as plt
import numpy as np

def f3(z):
    return z**5  - 3j * z**3 - 5 
def df3(z):
    return 5 * z ** 4 - 9j * z ** 2 

def newton_set3(z_c_r=0, z_c_i=0, zh = 10, zw=10, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = complex(-1.4205573789550424632,-1*1.2651761940027069472)
    r2 = complex(-0.90536791912805505289,0.57267999550642945109)
    r3 = complex(0.13330651271035444261,-1*1.11628997017925379394)
    r4 = complex(0.9804831880066371736,1.3919762936177064704)
    r5 = complex(1.21213559736610589987,0.41680987505782481966)

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df3(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f3(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color yellow
                    pixels[height-y-1,x] = (255 - count*multcol,223 , 0)
                elif abs(z-r2)<=eps:
                    # color red
                    pixels[height-y-1,x] = (255,100 - count*multcol, 0)
                elif abs(z-r3)<=eps:
                    # color blue
                    pixels[height-y-1,x] = (15,0,184 - count*multcol)
                elif abs(z-r4)<=eps:
                    # color green
                    pixels[height-y-1,x] = (137 - count*multcol,184 ,44)
                elif abs(z-r5)<=eps:
                    # color purple
                    pixels[height-y-1,x] = (138 - count*multcol,0,184)          
                else:   
                    pixels[height-y-1,x] = (255,255,255)
 
    return pixels

def display5(z_c_r=1, z_c_i=1, zh = 10, zw=10, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set3(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=z^3 - 2z + 2' )
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
display5(zoom=1)
display5(zoom=2)
display5(zoom=3)
display5(zoom=4)
display5(zoom=5)
# Out:
# zoom out
# Z region from ( -4.0 , -4.0 ) to ( 6.0 , 6.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -9.0 , -9.0 ) to ( 11.0 , 11.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -14.0 , -14.0 ) to ( 16.0 , 16.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -19.0 , -19.0 ) to ( 21.0 , 21.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -24.0 , -24.0 ) to ( 26.0 , 26.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print("zoom in")
display5(zoom=1)
display5(zoom=1/2)
display5(zoom=1/3)
display5(zoom=1/4)
display5(zoom=1/5)
display5(zoom=1/10)
display5(zoom=1/100)
display5(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -4.0 , -4.0 ) to ( 6.0 , 6.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.5 , -1.5 ) to ( 3.5 , 3.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.6666666666666665 , -0.6666666666666665 ) to ( 2.6666666666666665 , 2.6666666666666665 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.25 , -0.25 ) to ( 2.25 , 2.25 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( 0.0 , 0.0 ) to ( 2.0 , 2.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( 0.5 , 0.5 ) to ( 1.5 , 1.5 )
# ...

# %% [markdown]
# **Analysis:** As we can see this fractal is almost perfect due to the lack of white zones or points in it representation, this indicates thar for every complex value passed there is at least one root of convergence.
#
# we can see that al the zones of convergence are totally diferentiaded although they may lose precision due to the method used to plot them.
