# %%
#Libraries
import math
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# *   **NOMBRE:** Brayan Rolando Jr Portela Cabrera
# *   **GRUPO** Grupo 2
# *   **ID:** 1.014.284.576

# %% [markdown]
# # **Newton-Raphson Fractals and the Quadratic Equation:**
#
# > Newthon-Raphson is mathematical method established to find the roots of real and complex functions base on a series of terms obtained through the derivative of the a function and a set point, this methos consists in a series of iterations, yet can diverge from a point caotically due to its sensibility when handling the tangent in the derivatives.
#
#
# > Each term on the series is given by the next formula.
#
# $$ x_{n+1}  = x_n - \frac{f(x_n)}{f'(x_n)} $$
#
# > when the polynomial has roots with a multiplicity bigger than 1 then the method changes with an $m$ factor corresponding to the multiplicity of that root.
#
# $$ x_{n+1}  = x_n - m\frac{f(x_n)}{f'(x_n)} $$

# %% [markdown]
# ##*1. Plots*
# Plot the following functions in an $x$ range that include that include the vertex and the roots (if there are roots).
#
# *   $y = x^2$

# %%
def f1(z): #original function 
    return z ** 2

x = np.linspace(-1.0,1.0,100) #set of points
fig, ax = plt.subplots() #Plot funtion
ax.plot(x,f1(x))  #Plot parameter by axis
ax.axhline(y=0, color='k') #Color of the horizontal line
ax.axvline(x=0, color='k') #Color of the horizontal line
ax.grid(True, which='both') #Sets of the plot ehre the grid is going to be displayed
plt.title('f(x)=x^2') #title of the plot
plt.xlabel('X') #label of the x-axis
plt.ylabel('f(x) = x^2') #label of the y-axis
# Out:
# Text(0, 0.5, 'f(x) = x^2')

# %% [markdown]
# *   $y = (x-1)^2$

# %%
def f2(z): #original function 
    return (x-1)**2

x = np.linspace(0,2.0,100) #set of points
fig, ax = plt.subplots() #Plot funtion
ax.plot(x,f2(x))  #Plot parameter by axis
ax.axhline(y=0, color='k') #Color of the horizontal line
ax.axvline(x=0, color='k') #Color of the horizontal line
ax.grid(True, which='both') #Sets of the plot ehre the grid is going to be displayed
plt.title('f(x)=(x-1)^2') #title of the plot
plt.xlabel('X') #label of the x-axis
plt.ylabel('f(x) = (x-1)^2') #label of the y-axis
# Out:
# Text(0, 0.5, 'f(x) = (x-1)^2')

# %% [markdown]
# *   $y=x^2 - 1$

# %%
def f3(z): #original function 
    return (z**2)-1

x = np.linspace(-1.0,1.0,100) #set of points
fig, ax = plt.subplots() #Plot funtion
ax.plot(x,f3(x))  #Plot parameter by axis
ax.axhline(y=0, color='k') #Color of the horizontal line
ax.axvline(x=0, color='k') #Color of the horizontal line
ax.grid(True, which='both') #Sets of the plot ehre the grid is going to be displayed
plt.title('f(x)=x^2 - 1') #title of the plot
plt.xlabel('X') #label of the x-axis
plt.ylabel('f(x) = x^2 - 1') #label of the y-axis
# Out:
# Text(0, 0.5, 'f(x) = x^2 - 1')

# %% [markdown]
# *  $y=x^2 + 1$

# %%
def f4(z): #original function 
    return (z**2)+1

x = np.linspace(-1.0,1.0,100) #set of points
fig, ax = plt.subplots() #Plot funtion
ax.plot(x,f3(x))  #Plot parameter by axis
ax.axhline(y=0, color='k') #Color of the horizontal line
ax.axvline(x=0, color='k') #Color of the horizontal line
ax.grid(True, which='both') #Sets of the plot ehre the grid is going to be displayed
plt.title('f(x)=x^2 + 1') #title of the plot
plt.xlabel('X') #label of the x-axis
plt.ylabel('f(x) = x^2 + 1') #label of the y-axis
# Out:
# Text(0, 0.5, 'f(x) = x^2 + 1')

# %% [markdown]
# ##*2. Clasic and Po Shen Loh's Method*

# %% [markdown]
# The Clasic method to solve quadratic equations depends on the discriminat of the formula to determine wether if the root is real and complex, although it is not a dificcult method its far from being intuitive.
#
# $$ Ax^2 + Bx + C $$
#
# Then the roots are obteained by replacing the values in this formula.
#
# $$ x = \frac{-B \pm \sqrt{B^2 - 4AC}}{2A} $$

# %% [markdown]
# Po Shen Loh's method is based on a series of steps for finding solutions to quadratic equations, using the standard form of the quadratic equation:
#
# $$ Ax^2 + Bx + C \  \textrm{where} \ A=1$$
#
# 1.   If you find $r$ and $s$ with sum $-B$ and product $-C$ then $x^2 +Bx + C = (x-r)(x-s)$, and they are all the roots.
#
# 2.   Two numbers to sum $-B$ when they are $ -\frac{B}{2} \pm u $.
#
# 3.   Their product is $C$ when $ \frac{B^{2}}{4} - u^2 = C $.
#
# 4.   Square root always gives valid $u = \pm \sqrt{ \frac{B^2}{4} - C }$ .
#
# 5.   Thus $ -\frac{B}{2} \pm u $. work as $r$ and $s$, and are all the roots.
#
# 6. Then the general form of each root is $ -\frac{B}{2} \pm \sqrt{ \frac{B^2}{4} - C }$

# %%
def PSL(B,C): #Po Shen Loh's Method
  #Quadratic Equation x^2 + Bx + C = 0
  u = (((B**2)/4)-C)**0.5 #general expression for u
  mB = -B/2   #term -B without u
  ans = [mB + u,mB - u] 
  if (mB+u)==(mB-u):
    ans=mB+u
  return ans

# %%
def QEC(A,B,C): #Quadratic Equation Classic Method
  x1 = ((B*-1) + (B**2 - 4*A*C)**0.5)/2*A #First Root
  x2 = ((B*-1) - (B**2 - 4*A*C)**0.5)/2*A #Second root
  ans = [x1,x2]
  if x1==x2:
    ans = x1
  return ans

# %% [markdown]
# *   $ x^2 = 0$ Expanded form: $x^2 + 0x + 0 = 0$ .
#
# **Clasic Method**
#
# Replacing the corresponding values on the formula we obtain:
#
# $$ x = \frac{-B \pm \sqrt{B^2 - 4AC}}{2A}  = \frac{0 \pm \sqrt{0}}{2}  =  0  $$
#
# **PSL Method**
#
# The only roots existing for this polinomial term based on the method the roots are:
#
# 1. Two numbers to sum $0$ when they are $ -\frac{0}{2} \pm u  =  0  \pm u $.
#
# 2. Their product is $0$ when $ \frac{(0)^{2}}{4} - u^2 = 0  $ then $ \frac{0}{4} - 0 = 0  $
#
# 3. Square root always gives valid $u = \pm \sqrt{ \frac{0}{4} - 0  }=0$ .
#
# 4. Thus $ -\frac{-0}{2} \pm 0 $. work as $r = 0$ and $s = 0 $ are all the roots.

# %%
print("Po Shen Loh Method:" ,PSL(0,0))
print("Classic Method:" ,QEC(1,0,0))
# Out:
# Po Shen Loh Method: 0.0
# Classic Method: 0.0

# %% [markdown]
# *   $ (x-1)^2 = 0$ Expanded form: $x^2 -2x + 1 = 0$ .
#
# **Clasic Method**
#
# Replacing the corresponding values on the formula we obtain:
#
# $$ x = \frac{-B \pm \sqrt{B^2 - 4AC}}{2A}  = \frac{2 \pm \sqrt{4-4}}{2}  =  1  $$
#
# **PSL Method**
#
# 1. Two numbers to sum $2$ when they are $ -\frac{-2}{2} \pm u  =  1  \pm u $.
#
# 2. Their product is $1$ when $ \frac{(-2)^{2}}{4} - u^2 = 1  $ then $ \frac{4}{4} - u = 1  $
#
# 3. Square root always gives valid $u = \pm \sqrt{ \frac{4}{4} - 1  }=0$ .
#
# 4. Thus $ -\frac{-2}{2} \pm 0 $. work as $r = 1$ and $s = 1$ are all the roots.

# %%
print("Po Shen Loh Method:" ,PSL(-2,1))
print("Classic Method:" ,QEC(1,-2,1))
# Out:
# Po Shen Loh Method: 1.0
# Classic Method: 1.0

# %% [markdown]
# *   $ x^2 - 1 = 0$ Expanded form: $x^2 + 0x - 1 = 0$ .
#
# **Clasic Method**
#
# Replacing the corresponding values on the formula we obtain:
#
# $$ x = \frac{-B \pm \sqrt{B^2 - 4AC}}{2A}  = \frac{0 \pm \sqrt{0-4(1)(-1)}}{2}  =  \frac{0 \pm \sqrt{4}}{2}  = \pm 1$$
#
# **PSL Method**
# 1.   Two numbers to sum $-B = 0$ when they are $ -\frac{0}{2} \pm u  = 0 \pm u$.
#
# 2.   Their product is $C=-1$ when $ \frac{0^{2}}{4} - u^2 = 0-u^2 = -1 $.
#
# 3.   Square root always gives valid $u = \pm \sqrt{ \frac{0^2}{4} - (-1)} = \pm 1 $ .
#
# 4.   Thus $ 0 \pm 1 $. work as $r = 1$ and $s= -1$  are all the roots.

# %%
print("Po Shen Loh Method:" ,PSL(0,-1))
print("Classic Method:" ,QEC(1,0,-1))
# Out:
# Po Shen Loh Method: [1.0, -1.0]
# Classic Method: [1.0, -1.0]

# %% [markdown]
# *   $ x^2 + 1 = 0$ Expanded form: $x^2 + 0x + 1 = 0$ .
#
# **Clasic Method**
#
# Replacing the corresponding values on the formula we obtain:
#
# $$ x = \frac{-B \pm \sqrt{B^2 - 4AC}}{2A} = \frac{0 \pm \sqrt{0-4(1)(1)}}{2}  =  \frac{0 \pm \sqrt{-4}}{2}  = \frac{\pm 2i}{2} =\pm i$$
#
# **PSL Method**
#
# 1.   Two numbers to sum $-B = 0$ when they are $ -\frac{0}{2} \pm u  = 0 \pm u$.
#
# 2.   Their product is $C=1$ when $ \frac{0^{2}}{4} - u^2 = 0-u^2 = 1 $.
#
# 3.   Square root always gives valid $u = \pm \sqrt{ \frac{0^2}{4} - 1} = \pm i $ .
#
# 4.   Thus $ 0 \pm i $. work as $r = i$ and $s= -i$  are all the roots.

# %%
print("Po Shen Loh Method:" ,PSL(0,1))
print("Classic Method:" ,QEC(1,0,1))
# Out:
# Po Shen Loh Method: [(6.123233995736766e-17+1j), (-6.123233995736766e-17-1j)]
# Classic Method: [(6.123233995736766e-17+1j), (-6.123233995736766e-17-1j)]

# %% [markdown]
# ##*3.Newton Fractals*

# %% [markdown]
# ### Function 1 : $f(z)=z^2$

# %%
#First Function 

def f(z): #original function in z terms
    return z ** 2

def df(z): #derivative of the function
    return  2*z

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    # Mathematically this function only has one root, that is r = 0 the only point whte it touches the x-axis
    r1 = 0
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

# %%
def displayf1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=z^2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
displayf1(zoom=1)
displayf1(zoom=2)
displayf1(zoom=3)
displayf1(zoom=4)
displayf1(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
displayf1(zoom=1)
displayf1(zoom=1/2)
displayf1(zoom=1/3)
displayf1(zoom=1/4)
displayf1(zoom=1/5)
displayf1(zoom=1/10)
displayf1(zoom=1/100)
displayf1(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ### Function 2 : $f(z)=(z-1)^2$

# %%
#Second Function 

def f(z): #original function in z terms
    return (z-1)**2

def df(z): #derivative of the function
    return  2*(z-1)

def newton_set2(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    # Mathematically this function only has one root, that is r = 1 the only point whte it touches the x-axis
    r1 = 1
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - 2*(f(z)/dz) # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break    
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

# %%
def displayf2(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set2(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=(z-1)^2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
displayf2(zoom=1)
displayf2(zoom=2)
displayf2(zoom=3)
displayf2(zoom=4)
displayf2(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
displayf2(zoom=1)
displayf2(zoom=1/2)
displayf2(zoom=1/3)
displayf2(zoom=1/4)
displayf2(zoom=1/5)
displayf2(zoom=1/10)
displayf2(zoom=1/100)
displayf2(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ### Function 3 : $f(z)=z^2 -1$

# %%
#Third Function 

def f(z): #original function in z terms
    return (z**2)-1

def df(z): #derivative of the function
    return  2*z

def newton_set3(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    # Mathematically this function has two roots, those are r = +1 and r = -1 
    r1 = 1.0
    r2 = -1.0
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

# %%
def displayf3(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set3(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=(z-1)^2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
displayf3(zoom=1)
displayf3(zoom=2)
displayf3(zoom=3)
displayf3(zoom=4)
displayf3(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
displayf3(zoom=1)
displayf3(zoom=1/2)
displayf3(zoom=1/3)
displayf3(zoom=1/4)
displayf3(zoom=1/5)
displayf3(zoom=1/10)
displayf3(zoom=1/100)
displayf3(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ### Function 4 : $f(z)=z^2 +1$

# %%
#Fourth Function 

def f(z): #original function in z terms
    return (z**2)+1

def df(z): #derivative of the function
    return  2*z

def newton_set4(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    # Mathematically this function has two roots, those are r_i = 0.0+1i and r_i = 0.0-1i
    r1 = 0.0+1j
    r2 = 0.0-1j
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break

                    if f(z) == 0:
                      break    
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

# %%
def displayf4(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set4(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=(z-1)^2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
displayf4(zoom=1)
displayf4(zoom=2)
displayf4(zoom=3)
displayf4(zoom=4)
displayf4(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
displayf4(zoom=1)
displayf4(zoom=1/2)
displayf4(zoom=1/3)
displayf4(zoom=1/4)
displayf4(zoom=1/5)
displayf4(zoom=1/10)
displayf4(zoom=1/100)
displayf4(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ## *4.Newton iterates on the axis*

# %% [markdown]
# The only function who has complex solutions corresponds to $z^2 + 1$ so iterations for only this one are going to be shown.
#
# *   Iterations from: $20.0 + 0.0j$

# %%
def f(z): #original function in z terms
    return (z**2)+1

def df(z): #derivative of the function
    return  2*z

z=20.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *   Iterations from: $-20.0 + 0.0j$

# %%
z=-20.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
#   Iterations from: $0.0 + 20.0j$

# %%
z=0.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
#   Iterations from: $0.0 - 20.0j$

# %%
z=0.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# **Conclusion:** Whenever a complex number whose imaginary part is $0$, is pased to the method the iterations diverge that is because this expresion has no real root so the method never find a value to settle, but whenever a complex number whose real part is $0$ the method quicly converges to its correponding imaginary root, if the imaginary part is negative the method converges to $-i$ and if the imgaginary part is positve it converges to $i$, then:
#
# $$\textrm{ If } y \  \textrm{is a complex number that x = a +bj then:}$$
#
# $ Re(x) \neq 0$ and  $Im(x)  \nexists \ $,  then the method diverges and never settles to a root in this polynomial.
#
# $ Re(x) \nexists$ and  $Im(x) \neq 0 \ $ , then the method converges to its  corresponding to a root in this polynomial.

# %% [markdown]
# ## *5.Newton iterates on the diagonals*

# %% [markdown]
# The only function who has complex solutions corresponds to $z^2 + 1$ so iterations for only this one are going to be shown.
#
#
# *   Iterations from: $20.0 + 20.0j$

# %%
def f(z): #original function in z terms
    return (z**2)+1

def df(z): #derivative of the function
    return  2*z

z=20.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=20.0 + 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *   Iterations from: $20.0 - 20.0j$

# %%
z=20.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=20.0 + 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# *   Iterations from: $-20.0 + 20.0j$

# %%
z=-20.0 + 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 + 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# **Note:** In this quadrant due to the negative value in the real part the behaviour for both parts of the complex number is the same.

# %% [markdown]
#  Iterations from: $-20.0 - 20.0j$

# %%
z=-20.0 - 20.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-20.0 - 20.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# **Conclusion:** Whenever a complex number in the diagonals of the complex plane is pased to the method the iterations conver quickly to 0 , it does not consider the roots in the complex numbers or the divergence in the real numbers.
